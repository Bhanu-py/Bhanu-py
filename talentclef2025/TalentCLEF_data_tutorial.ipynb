# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhanu-py/Bhanu-py/blob/main/talentclef2025/TalentCLEF_data_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tutorial: Downloading and Loading Training Data from Zenodo for TalentCLEF
#
# This notebook provides a step-by-step guide on downloading and loading training data for the TalentCLEF shared-task, hosted on [Zenodo](https://doi.org/10.5281/zenodo.14002665).
#
# TalentCLEF is an initiative to advance Natural Language Processing (NLP) in Human Capital Management (HCM). It aims to create a public benchmark for model evaluation and promote collaboration to develop fair, multilingual, and flexible systems that improve Human Resources (HR) practices across different industries.
#
# This shared-task's inaugural edition is part of the [Conference and Labs of the Evaluation Forum (CLEF)](https://clef2025.clef-initiative.eu/index.php?page=Pages/labs.html), scheduled to be held in Madrid in 2025. If you are interested in registering, you can find registration form [here](https://clef2025-labs-registration.dei.unipd.it/).
#
# <img src="https://github.com/TalentCLEF/talentclef/blob/main/logo_talentclef.png?raw=true" alt="TalentCLEF logo" width="200"/>
# <img src="https://talentclef.github.io/talentclef/docs/talentclef-2025/workshop/logo_clef_madrid.png" alt="TalentCLEF logo" width="150"/>
#
# In this notebook you will learn how to download and load the training data of the task.

# %% [markdown]
# ## Download files

# %% [markdown]
# First, let's download the Task A and Task B zip files directly from Zenodo.

# %%
# Download
# !wget https://zenodo.org/records/14693201/files/TaskA.zip
# !wget https://zenodo.org/records/14693201/files/TaskB.zip
# Unzip
# !unzip TaskA.zip -d taskA
# !unzip TaskB.zip -d taskB
# Out:
# --2025-01-28 09:42:33--  https://zenodo.org/records/14693201/files/TaskA.zip
# Resolving zenodo.org (zenodo.org)... 188.185.43.25, 188.185.48.194, 188.185.45.92, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 863884 (844K) [application/octet-stream]
# Saving to: ‘TaskA.zip’
#
# TaskA.zip           100%[===================>] 843.64K  1.65MB/s    in 0.5s
#
# 2025-01-28 09:42:34 (1.65 MB/s) - ‘TaskA.zip’ saved [863884/863884]
#
# --2025-01-28 09:42:34--  https://zenodo.org/records/14693201/files/TaskB.zip
# Resolving zenodo.org (zenodo.org)... 188.185.43.25, 188.185.48.194, 188.185.45.92, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4192240 (4.0M) [application/octet-stream]
# Saving to: ‘TaskB.zip’
#
# TaskB.zip           100%[===================>]   4.00M  4.97MB/s    in 0.8s
#
# 2025-01-28 09:42:35 (4.97 MB/s) - ‘TaskB.zip’ saved [4192240/4192240]
#
# Archive:  TaskA.zip
#    creating: taskA/test/
#    creating: taskA/training/
#    creating: taskA/training/english/
#   inflating: taskA/training/english/taskA_training_en.tsv
#    creating: taskA/training/spanish/
#   inflating: taskA/training/spanish/taskA_training_es.tsv
#    creating: taskA/training/german/
#   inflating: taskA/training/german/taskA_training_de.tsv
#    creating: taskA/validation/
# Archive:  TaskB.zip
#    creating: taskB/test/
#    creating: taskB/training/
#   inflating: taskB/training/job2skill.tsv
#   inflating: taskB/training/jobid2terms.json
#   inflating: taskB/training/skillid2terms.json
#    creating: taskB/validation/

# %% [markdown]
# ## Task A files

# %% [markdown]
# ### Training data

# %% [markdown]
# The training data for Task A is located in different folders within 'training', based on the language of the data:

# %%
spanish_training = "/content/taskA/training/spanish/taskA_training_es.tsv"
english_training = "/content/taskA/training/english/taskA_training_en.tsv"
german_training = "/content/taskA/training/german/taskA_training_de.tsv"

# %% [markdown]
# As explained on [the data description page in TalentCLEF website](https://talentclef.github.io/talentclef/docs/talentclef-2025/data/description_corpus/), the training set is provided in a tabular format where each row displays two related job titles (`jobtitle_1`, `jobtitle_2`) along with the ESCO identifier they originate from (`id`) and the ISCO family to which the ESCO identifier belongs(`family_id`), that might be useful to process the data for model training.

# %%
import pandas as pd
spanish_df = pd.read_csv(spanish_training,sep="\t", names=["family_id","id","jobtitle_1","jobtitle_2"])
english_df = pd.read_csv(english_training,sep="\t", names=["family_id","id","jobtitle_1","jobtitle_2"])
german_df = pd.read_csv(german_training,sep="\t", names=["family_id","id","jobtitle_1","jobtitle_2"])

# %%
spanish_df
# Out:
#                                    family_id  \
# 0      http://data.europa.eu/esco/isco/C0110
# 1      http://data.europa.eu/esco/isco/C0110
# 2      http://data.europa.eu/esco/isco/C0110
# 3      http://data.europa.eu/esco/isco/C0110
# 4      http://data.europa.eu/esco/isco/C0110
# ...                                      ...
# 20719  http://data.europa.eu/esco/isco/C9629
# 20720  http://data.europa.eu/esco/isco/C9629
# 20721  http://data.europa.eu/esco/isco/C9629
# 20722  http://data.europa.eu/esco/isco/C9629
# 20723  http://data.europa.eu/esco/isco/C9629
#
#                                                       id  \
# 0      http://data.europa.eu/esco/occupation/f2cc5978...
# 1      http://data.europa.eu/esco/occupation/f2cc5978...
# 2      http://data.europa.eu/esco/occupation/f2cc5978...
# 3      http://data.europa.eu/esco/occupation/f2cc5978...
# 4      http://data.europa.eu/esco/occupation/f2cc5978...
# ...                                                  ...
# 20719  http://data.europa.eu/esco/occupation/1f1a45a8...
# 20720  http://data.europa.eu/esco/occupation/1f1a45a8...
# 20721  http://data.europa.eu/esco/occupation/7f346896...
# 20722  http://data.europa.eu/esco/occupation/7f346896...
# 20723  http://data.europa.eu/esco/occupation/7f346896...
#
#                                             jobtitle_1  \
# 0                                    jefe de escuadrón
# 1                               comandante de aeronave
# 2                                           instructor
# 3                               comandante de aeronave
# 4                               oficial de operaciones
# ...                                                ...
# 20719                          encargado de vestuarios
# 20720  encargado de vestuarios/encargada de vestuarios
# 20721                                      acomodadora
# 20722                                       acomodador
# 20723                                       acomodador
#
#                           jobtitle_2
# 0                         instructor
# 1            instructor de simulador
# 2      oficial del Ejército del Aire
# 3                         instructor
# 4                        instructora
# ...                              ...
# 20719        encargada de vestidores
# 20720        encargada de vestuarios
# 20721         acomodador/acomodadora
# 20722         acomodador/acomodadora
# 20723                    acomodadora
#
# [20724 rows x 4 columns]

# %%
english_df[english_df['jobtitle_1'].str.contains('consumer')]
# Out:
#                                    family_id  \
# 2969   http://data.europa.eu/esco/isco/C1420
# 2971   http://data.europa.eu/esco/isco/C1420
# 3723   http://data.europa.eu/esco/isco/C2113
# 3724   http://data.europa.eu/esco/isco/C2113
# 3725   http://data.europa.eu/esco/isco/C2113
# 8627   http://data.europa.eu/esco/isco/C2422
# 13277  http://data.europa.eu/esco/isco/C3122
# 13280  http://data.europa.eu/esco/isco/C3122
# 13282  http://data.europa.eu/esco/isco/C3122
# 13283  http://data.europa.eu/esco/isco/C3122
# 13284  http://data.europa.eu/esco/isco/C3122
# 13285  http://data.europa.eu/esco/isco/C3122
# 15013  http://data.europa.eu/esco/isco/C3312
# 15039  http://data.europa.eu/esco/isco/C3312
# 15040  http://data.europa.eu/esco/isco/C3312
# 16718  http://data.europa.eu/esco/isco/C3359
# 16719  http://data.europa.eu/esco/isco/C3359
# 16721  http://data.europa.eu/esco/isco/C3359
# 16723  http://data.europa.eu/esco/isco/C3359
# 16724  http://data.europa.eu/esco/isco/C3359
# 16725  http://data.europa.eu/esco/isco/C3359
# 20153  http://data.europa.eu/esco/isco/C5223
# 20159  http://data.europa.eu/esco/isco/C5223
# 23735  http://data.europa.eu/esco/isco/C7421
# 23737  http://data.europa.eu/esco/isco/C7421
# 23740  http://data.europa.eu/esco/isco/C7421
# 23742  http://data.europa.eu/esco/isco/C7421
# 24755  http://data.europa.eu/esco/isco/C7543
# 24759  http://data.europa.eu/esco/isco/C7543
# 24775  http://data.europa.eu/esco/isco/C7543
# 24777  http://data.europa.eu/esco/isco/C7543
# 24778  http://data.europa.eu/esco/isco/C7543
# 24779  http://data.europa.eu/esco/isco/C7543
# 24780  http://data.europa.eu/esco/isco/C7543
# 24781  http://data.europa.eu/esco/isco/C7543
# 24782  http://data.europa.eu/esco/isco/C7543
# 24783  http://data.europa.eu/esco/isco/C7543
#
#                                                       id  \
# 2969   http://data.europa.eu/esco/occupation/d8e5410b...
# 2971   http://data.europa.eu/esco/occupation/d8e5410b...
# 3723   http://data.europa.eu/esco/occupation/8606c0fd...
# 3724   http://data.europa.eu/esco/occupation/8606c0fd...
# 3725   http://data.europa.eu/esco/occupation/8606c0fd...
# 8627   http://data.europa.eu/esco/occupation/3826cb92...
# 13277  http://data.europa.eu/esco/occupation/40517ed4...
# 13280  http://data.europa.eu/esco/occupation/40517ed4...
# 13282  http://data.europa.eu/esco/occupation/40517ed4...
# 13283  http://data.europa.eu/esco/occupation/40517ed4...
# 13284  http://data.europa.eu/esco/occupation/40517ed4...
# 13285  http://data.europa.eu/esco/occupation/40517ed4...
# 15013  http://data.europa.eu/esco/occupation/5e4d156a...
# 15039  http://data.europa.eu/esco/occupation/32fafe2c...
# 15040  http://data.europa.eu/esco/occupation/32fafe2c...
# 16718  http://data.europa.eu/esco/occupation/cb60beab...
# 16719  http://data.europa.eu/esco/occupation/cb60beab...
# 16721  http://data.europa.eu/esco/occupation/cb60beab...
# 16723  http://data.europa.eu/esco/occupation/cb60beab...
# 16724  http://data.europa.eu/esco/occupation/cb60beab...
# 16725  http://data.europa.eu/esco/occupation/cb60beab...
# 20153  http://data.europa.eu/esco/occupation/4dc6e03f...
# 20159  http://data.europa.eu/esco/occupation/4dc6e03f...
# 23735  http://data.europa.eu/esco/occupation/f8ab2e08...
# 23737  http://data.europa.eu/esco/occupation/f8ab2e08...
# 23740  http://data.europa.eu/esco/occupation/f8ab2e08...
# 23742  http://data.europa.eu/esco/occupation/f8ab2e08...
# 24755  http://data.europa.eu/esco/occupation/753939ad...
# 24759  http://data.europa.eu/esco/occupation/753939ad...
# 24775  http://data.europa.eu/esco/occupation/68ad860f...
# 24777  http://data.europa.eu/esco/occupation/68ad860f...
# 24778  http://data.europa.eu/esco/occupation/68ad860f...
# 24779  http://data.europa.eu/esco/occupation/68ad860f...
# 24780  http://data.europa.eu/esco/occupation/68ad860f...
# 24781  http://data.europa.eu/esco/occupation/68ad860f...
# 24782  http://data.europa.eu/esco/occupation/68ad860f...
# 24783  http://data.europa.eu/esco/occupation/68ad860f...
#
#                                          jobtitle_1  \
# 2969              consumer electronics shop manager
# 2971             consumer electronics store manager
# 3723        sensory and consumer research scientist
# 3724                 consumer and sensory scientist
# 3725        sensory and consumer research scientist
# 8627                    consumer protection officer
# 13277           consumer goods production forewoman
# 13280             consumer goods production foreman
# 13282       consumer goods quality control operator
# 13283  consumer goods production quality supervisor
# 13284           consumer goods production forewoman
# 13285  consumer goods production quality supervisor
# 15013                               consumer banker
# 15039                       consumer credit manager
# 15040                       consumer credit manager
# 16718                 consumer rights legal advisor
# 16719                 consumer rights legal advisor
# 16721                       consumer rights advisor
# 16723                       consumer rights adviser
# 16724                       consumer rights advisor
# 16725                 consumer rights legal adviser
# 20153       consumer electronics specialised seller
# 20159              consumer electronics salesperson
# 23735                                      consumer
# 23737                consumer electronics repairman
# 23740                consumer electronics repairman
# 23742        consumer electronics repair technician
# 24755      consumer goods quality control inspector
# 24759              consumer goods quality inspector
# 24775      consumer goods quality control inspector
# 24777     consumer products assembly line inspector
# 24778   consumer products quality control inspector
# 24779   consumer products quality control inspector
# 24780   consumer products quality control inspector
# 24781        consumer goods assembly line inspector
# 24782           consumer goods compliance inspector
# 24783        consumer goods assembly line inspector
#
#                                       jobtitle_2
# 2969                            ICT shop manager
# 2971                             IT shop manager
# 3723                  sensory research scientist
# 3724                     sensory science advisor
# 3725                            bakery scientist
# 8627              policy manager for competition
# 13277              production machine supervisor
# 13280                        production overseer
# 13282         consumer goods production overseer
# 13283                   manufacturing supervisor
# 13284                   quality control operator
# 13285                   quality control operator
# 15013                  bank relationship manager
# 15039                     credit control manager
# 15040                branch credit administrator
# 16718              consumer rights legal adviser
# 16719                     food hygiene inspector
# 16721              consumer rights legal adviser
# 16723              consumer rights legal advisor
# 16724              consumer rights legal advisor
# 16725                     legal services adviser
# 20153                       computer salesperson
# 20159  computer and peripheral units salesperson
# 23735                                  repairman
# 23737                                   consumer
# 23740            consumer electronics technician
# 23742                                 technician
# 24755                         assembly inspector
# 24759      assembly quality compliance inspector
# 24775     consumer goods assembly line inspector
# 24777          consumer goods assembly inspector
# 24778                         material inspector
# 24779       consumer products assembly inspector
# 24780                             toys inspector
# 24781                         assembly inspector
# 24782        consumer products quality inspector
# 24783                             toys inspector

# %%
german_df.head(2)
# Out:
#                                family_id  \
# 0  http://data.europa.eu/esco/isco/C0110
# 1  http://data.europa.eu/esco/isco/C0110
#
#                                                   id            jobtitle_1  \
# 0  http://data.europa.eu/esco/occupation/f2cc5978...   Staffelkommandantin
# 1  http://data.europa.eu/esco/occupation/f2cc5978...  Luftwaffenoffizierin
#
#                                 jobtitle_2
# 0                                Kommodore
# 1  Luftwaffenoffizier/Luftwaffenoffizierin

# %% [markdown]
# ## Task B files

# %% [markdown]
# ### Training

# %% [markdown]
# The training data for Task B is shared in 3 files:
# - `job2skill.tsv`: This file has been curated to include the most representative skills for each job title in ESCO. This file contains three columns:
#   - `job_id`: ESCO identifier for the job position.
#   - `skill_id`: ESCO identifier for the skill.
#   - `rel_type`: Indicator specifying whether the skill_id is essential or optional for a specific job_id. It can have the value “essential” or “optional.”
#
# - `jobid2terms.json`: This JSON file contains job_id identifiers used in the training set for Task A as keys, and a list of valid lexical variants for each identifier as values.
#
# - `skillid2terms.json`: This JSON file contains skill_id identifiers as keys, and a list of valid lexical variants for each identifier as values.

# %%
taskB_path = "/content/taskB/training"

# %% [markdown]
# Let's read the data

# %%
# Read job2skill file
import os
job2skill = pd.read_csv(os.path.join(taskB_path, 'job2skill.tsv'),
                        sep="\t",
                        names=["job_id","skill_id","rel_type"])
job2skill.head()
# Out:
#                                               job_id  \
# 0  http://data.europa.eu/esco/occupation/00030d09...
# 1  http://data.europa.eu/esco/occupation/00030d09...
# 2  http://data.europa.eu/esco/occupation/00030d09...
# 3  http://data.europa.eu/esco/occupation/00030d09...
# 4  http://data.europa.eu/esco/occupation/00030d09...
#
#                                             skill_id   rel_type
# 0  http://data.europa.eu/esco/skill/93a68dcb-3dc6...  essential
# 1  http://data.europa.eu/esco/skill/05bc7677-5a64...  essential
# 2  http://data.europa.eu/esco/skill/860be36a-d19b...  essential
# 3  http://data.europa.eu/esco/skill/fed5b267-73fa...  essential
# 4  http://data.europa.eu/esco/skill/f64fe2c2-d090...  essential

# %%
# Read json files
import json

with open(os.path.join(taskB_path,"jobid2terms.json"), 'r') as file:
    jobid2terms = json.load(file)

with open(os.path.join(taskB_path,"skillid2terms.json"), 'r') as file:
    skillid2terms = json.load(file)

# %% [markdown]
# We can map the values to the relation dataframe:

# %%
job2skill["job_terms"] = job2skill["job_id"].map(jobid2terms)
job2skill["skill_terms"] = job2skill["skill_id"].map(skillid2terms)

# %% [markdown]
# Let's see the skills for a specific job_id.

# %%
job_id_to_search = job2skill.job_id.to_list()[8]
job_data = job2skill[job2skill.job_id == job_id_to_search]

# %% [markdown]
# The job titles of the selected job_id are:

# %%
job_data.job_terms.iloc[0]
# Out:
# ['technical director',
#  'technical and operations director',
#  'head of technical',
#  'director of technical arts',
#  'head of technical department',
#  'technical supervisor',
#  'technical manager']

# %% [markdown]
# For that job_id we fin 9 essential skills and 1 optional skill:

# %%
job_data.rel_type.value_counts()
# Out:
# rel_type
# essential    9
# optional     1
# Name: count, dtype: int64

# %% [markdown]
# The list of skills related to the job_id are:

# %%
job_data.skill_terms.to_list()
# Out:
# [['promote health and safety',
#   'promote importance of health and safety',
#   'promoting health and safety',
#   'advertise health and safety'],
#  ['organise rehearsals',
#   'organise rehearsal',
#   'organize rehearsals',
#   'plan rehearsals',
#   'arrange rehearsals',
#   'organising rehearsals',
#   'schedule rehearsals'],
#  ['negotiate health and safety issues with third parties',
#   'agree with third parties on health and safety',
#   'negotiate issues on health and safety with third parties',
#   'negotiate with third parties on health and safety issues',
#   'negotiate health and safety matters with third parties'],
#  ['theatre techniques',
#   'theatre technique',
#   'theatre approaches',
#   'theatre methods'],
#  ['coordinate technical teams in artistic productions',
#   'supervise technical teams during a production',
#   'coordinate technical teams during artistic production',
#   'coordinate technical teams',
#   'coordinate technical teams for artistic production'],
#  ['write risk assessment on performing arts production',
#   'write assessment of risks about performing arts production',
#   'identify risk measures to be implemented for arts production',
#   'describe risk assessment measures when performing arts production',
#   'write risk assessment regarding production of performing arts'],
#  ["adapt to artists' creative demands",
#   'meet demands by creative artists',
#   'adapt to demands by creative artists',
#   'adapt to creative demands of artists',
#   "adapt to artists' creative vision"],
#  ['coordinate with creative departments',
#   'liaise with other artistic departments',
#   'coordinate with creation departments',
#   'coordinate with departments of creativity',
#   'consult with other creative units'],
#  ['adapt designers’ work to the performance venue',
#   'adapt designers’ work to the performance venue',
#   'adapt the work of all involved to the performance venue',
#   "adapt designers' work to venue of performance",
#   'adapt work of designers to the performance venue',
#   "modify designers' work according to performance location"],
#  ['write technical riders',
#   'collaborate for the creation of technical riders',
#   'contribute to the creation of technical riders',
#   'participate in the creation of technical riders',
#   'participate in the writing of technical riders']]

# %%
job2skill.job_id.to_list()[8]
# Out:
# 'http://data.europa.eu/esco/occupation/00030d09-2b3a-4efd-87cc-c4ea39d27c34'
